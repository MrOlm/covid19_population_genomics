# %%
import os
import sys
import glob
import scipy
import matplotlib
import numpy as np
import pandas as pd
import seaborn as sns
from collections import defaultdict
from matplotlib import pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages

from subprocess import call

# %matplotlib inline
sns.set_style('whitegrid')
pd.set_option('display.max_rows', 100)
matplotlib.rcParams['ps.fonttype'] = 42
matplotlib.rcParams['pdf.fonttype'] = 42
pd.set_option('display.max_columns', 100)

# %%
def SRA_to_bioproject(accession):
    '''
    From an SRA (like SRR1883283) return a biosample
    '''
    from Bio import Entrez
    Entrez.email = "mattolm@gmail.com"

    # GO FROM SRA TO ID
    #accession = 'SRX1883283'
    handle = Entrez.esearch(db='sra', term=accession, retmode='text')
    record = Entrez.read(handle)
    handle.close()
    ID = record['IdList'][0]
    #return ID
    
    # ELINK FROM SRA ID TO BIOSAMPLE ID
    accession = ID
    handle = Entrez.elink(dbfrom="sra", retmax=10, id=accession, linkname="sra_bioproject")
    record = Entrez.read(handle)
    handle.close()
    BID = [link["Id"] for link in record[0]["LinkSetDb"][0]["Link"]][0]
    #return BID

    # SUMMARY FROM BIOSAMPLE ID TO TERM
    handle = Entrez.esummary(db="bioproject", id=BID)
    record = Entrez.read(handle)
    handle.close()
    BioSample = record['DocumentSummarySet']['DocumentSummary'][0]['Project_Acc']
    
    return BioSample

# %% [markdown]
# # Set up

# %%
val_loc = '/home/mattolm/user_data/Covid_19/Pipeline/Jupyter/validated_downloads.txt'
meta_loc = '/home/mattolm/user_data/Covid_19/Pipeline/Metadata/metadata.xlsx'

THREADS = 6

VALIDATED_RUNS = []
with open(val_loc, 'r') as o:
    for line in o.readlines():
        VALIDATED_RUNS.append(line.strip())
VALIDATED_RUNS = set(VALIDATED_RUNS)

BioMeta = pd.read_excel(meta_loc, sheet_name='BioProjects')
BioMeta.head()
# Out:
#     BioProject                                               Link  \
# 0  PRJNA615032  https://www.ncbi.nlm.nih.gov/bioproject/?term=...
# 1  PRJNA610428  https://www.ncbi.nlm.nih.gov/bioproject/?term=...
# 2  PRJNA613958  https://www.ncbi.nlm.nih.gov/bioproject/?term=...
# 3  PRJNA614546  https://www.ncbi.nlm.nih.gov/bioproject/?term=...
# 4  PRJNA616446  https://www.ncbi.nlm.nih.gov/bioproject/?term=...
#
#                                                Group        Method  \
# 0             Icahn School of Medicine at Mount Sina       RNA-seq
# 1                           UNIVERSITY OF WASHINGTON       RNA-seq
# 2  The Peter Doherty Institute for Infection and ...  PCR_ARTIC v1
# 3                                   Paragon Genomics         Mixed
# 4  Hubei Provincial Center for Disease Control an...       RNA-seq
#
#                                     Publication link  \
# 0  https://www.biorxiv.org/content/10.1101/2020.0...
# 1                                                NaN
# 2                                                NaN
# 3  https://www.biorxiv.org/content/10.1101/2020.0...
# 4  https://www.biorxiv.org/content/10.1101/2020.0...
#
#                                    Publication title  \
# 0  SARS-CoV-2 launches a unique transcriptional s...
# 1                                                NaN
# 2                                                NaN
# 3  High sensitivity detection of coronavirus SARS...
# 4  Genome-wide data inferring the evolution and p...
#
#                                          Description
# 0    Looking at the response of human cells to COVID
# 1                                                NaN
# 2                                                NaN
# 3  Evaluating lots of things; worth following up....
# 4                                 Sequencing genomes

# %% [markdown]
# # Get a list of all SRA samples

# %%
from datetime import date
today = date.today()
d4 = today.strftime("%d_%m_%Y")
dloc = '/home/mattolm/user_data/Covid_19/Pipeline/Jupyter/{0}_SRA.tsv'.format(d4)

SEARCH_STRING = '(\\"Severe acute respiratory syndrome coronavirus 2\\"[Organism] OR SARS-CoV-2[All Fields]) AND \\"platform illumina\\"[Properties]'

! pysradb search "$SEARCH_STRING" --detailed --saveto "$dloc"

SRdb = pd.read_csv(dloc, sep='\t')
SRdb['Run'] = SRdb['run_accession']
SRdb = SRdb[~SRdb['run_accession'].isna()]

# Add BioProject
SRdb['BioProject'] = [SRA_to_bioproject(r) for r in SRdb['Run']]

# Any unknown BioProjects?
unk = set(SRdb['BioProject'].tolist()) - set(BioMeta['BioProject'].tolist())
if len(unk) == 0:
    print("All BioProjects are known")
else:
    print("{0} new BioProjects with no info".format(len(unk)))
    print("\n".join(list(unk)))
# Out:
# /home/mattolm/miniconda3/lib/python3.7/site-packages/tqdm/std.py:658: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel
# /home/mattolm/miniconda3/lib/python3.7/site-packages/tqdm/std.py:658: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel
# All BioProjects are known

# %%
# Filter out irrelevant bioprojects
SRdb = SRdb[~SRdb['BioProject'].isin(BioMeta[BioMeta['Method'] == 'IRRELEVANT']['BioProject'])]
NEW = set(SRdb['Run'].tolist())
print("{0} new samples (and {1} already processed = {2} total (including irrelevant already processed))".format(len(NEW - VALIDATED_RUNS), len(VALIDATED_RUNS), len(SRdb)))
# Out:
# 90 new samples (and 77 already processed = 159 total (including irrelevant already processed))

# %% [markdown]
# # START PROCESSING!

# %% [markdown]
# # Download samples that need downloading

# %%
import subprocess
def check_sra_file(file):
    cmd = "/usr/bin/vdb-validate {0}".format(file)
    try:
        output = subprocess.check_output(
            cmd, stderr=subprocess.STDOUT, shell=True,
            universal_newlines=True)
        final_out = output.split('\n')[-2]
        return True
    except Exception as exc:
        return False

# %%
base_loc = '/home/mattolm/user_data/Covid_19/reads/'
odir = '/home/mattolm/user_data/Covid_19/Pipeline/test/'

SRdb['sra_file'] = [base_loc + x for x in SRdb['Run']]
SRdb['sra_file_consistant'] = [(R in VALIDATED_RUNS) for R in SRdb['Run']]
SRdb['sra_file_consistant'] = [check_sra_file(x) if y == False else y for x, y in zip(SRdb['sra_file'], SRdb['sra_file_consistant'])]

TOTAL_LOOPS = 50
loop = 0
while len(SRdb[SRdb['sra_file_consistant'] == False]) > 0:
    print('Running loop {0}; downloading {1} new files'.format(loop, len(SRdb[SRdb['sra_file_consistant'] == False])))
    cmd_loc = '/home/mattolm/user_data/Covid_19/Pipeline/Jupyter/cmds/{0}_download.txt'.format(d4)
    with open(cmd_loc, 'w') as o:
        for i, row in SRdb[SRdb['sra_file_consistant'] == False].iterrows():
            o.write("wget -c {0} -O {1}\n".format(row['sra_url'], row['sra_file']))
    cmd = "cat {0} | parallel -j {1}".format(cmd_loc, THREADS)
    call(cmd, shell=True)
            
    SRdb['sra_file_consistant'] = [check_sra_file(x) if y == False else y for x, y in zip(SRdb['sra_file'], SRdb['sra_file_consistant'])]
    loop += 1
    if loop == TOTAL_LOOPS:
        break
        
if len(SRdb[SRdb['sra_file_consistant'] == False]) > 0:
    print("THE FOLLOWING HAVE PROBLEMS:")
    for i, row in SRdb[SRdb['sra_file_consistant'] == False].iterrows():
        print("/usr/bin/vdb-validate {0}".format(row['sra_file']))
        print("wget -c {0} -O {1}\n".format(row['sra_url'], row['sra_file']))
# Out:
# Running loop 0; downloading 23 new files

# %%
if len(SRdb[SRdb['sra_file_consistant'] == False]) > 0:
    print("THE FOLLOWING HAVE PROBLEMS:")
    for i, row in SRdb[SRdb['sra_file_consistant'] == False].iterrows():
        print("/usr/bin/vdb-validate {0}".format(row['sra_file']))
        print("wget -c {0} -O {1}\n".format(row['sra_url'], row['sra_file']))
else:
    print("All are good!")
# Out:
# All are good!

# %%
# Save new validations
VALIDATED_RUNS = VALIDATED_RUNS.union(set(SRdb[SRdb['sra_file_consistant'] == True]['Run'].tolist()))
with open('/home/mattolm/user_data/Covid_19/Pipeline/Jupyter/validated_downloads.txt', 'w') as o:
    for v in VALIDATED_RUNS:
        o.write(v + '\n')

# %% [markdown]
# ## FastqQ Dump

# %%
base_loc = '/home/mattolm/user_data/Covid_19/reads/'

SRdb['fastq1'] = [x + '_1.fastq' for x in SRdb['sra_file']]
SRdb['fastq2'] = [x + '_2.fastq' for x in SRdb['sra_file']]

SRdb['fastq1_exists'] = [os.path.exists(x) for x in SRdb['fastq1']]
SRdb['fastq2_exists'] = [os.path.exists(x) for x in SRdb['fastq2']]

loop = 0
MISSING_FASTA = SRdb[SRdb['fastq1_exists'] == False]
while len(MISSING_FASTA) > 0:
    print("Loop {0} - {1} samples are missing their fastq dumps".format(loop, len(MISSING_FASTA)))
    
    cmd_loc = '/home/mattolm/user_data/Covid_19/Pipeline/Jupyter/cmds/{0}_dump.txt'.format(d4)
    with open(cmd_loc, 'w') as o:
        for i, row in MISSING_FASTA.iterrows():
            o.write("fastq-dump {0} --split-files -O {1}".format(row['sra_file'], base_loc) + '\n')
    cmd = "cat {0} | parallel -j {1}".format(cmd_loc, THREADS)
    call(cmd, shell=True)

    SRdb['fastq1_exists'] = [os.path.exists(x) for x in SRdb['fastq1']]
    MISSING_FASTA = SRdb[SRdb['fastq1_exists'] == False]
    loop += 1
    
SRdb['LibraryLayout'] = ['PAIRED' if t else 'SINGLE' for t in SRdb['fastq2_exists']]
# Out:
# Loop 0 - 90 samples are missing their fastq dumps

# %%
for x, db in SRdb.groupby('LibraryLayout'):
    print(x)
    print(db['fastq2_exists'].value_counts())
# Out:
# PAIRED
# True    55
# Name: fastq2_exists, dtype: int64
# SINGLE
# False    104
# Name: fastq2_exists, dtype: int64

# %% [markdown]
# ## Process reads

# %%
SRdb['filtered_fastq1'] = ['/home/mattolm/user_data/Covid_19/reads/filtered/' + os.path.basename(rp).replace('_1.fastq', '_rep1.fastq').replace('_rep1.fastq', '_bbduk_1.fastq') for rp in SRdb['fastq1']]
SRdb['filtered_fastq2'] = ['/home/mattolm/user_data/Covid_19/reads/filtered/' + os.path.basename(rp).replace('_2.fastq', '_rep2.fastq').replace('_rep2.fastq', '_bbduk_2.fastq') for rp in SRdb['fastq2']]
SRdb['filtered_fastqS'] = ['/home/mattolm/user_data/Covid_19/reads/filtered/' + os.path.basename(rp).replace('_1.fastq', '_rep1.fastq').replace('_rep1.fastq', '_bbduk.fastq') for rp in SRdb['fastq1']]

SRdb['filtered_fastq1_exists'] = [os.path.exists(x) for x in SRdb['filtered_fastq1']]
SRdb['filtered_fastq2_exists'] = [os.path.exists(x) for x in SRdb['filtered_fastq2']]
SRdb['filtered_fastqS_exists'] = [os.path.exists(x) for x in SRdb['filtered_fastqS']]

# %%
from subprocess import call
def process_reads(r1, r2, outfolder):
    # repair
    rr1 = outfolder + os.path.basename(r1).replace('_1.fastq', '_rep1.fastq')
    rr2 = outfolder + os.path.basename(r2).replace('_2.fastq', '_rep2.fastq')
    cmd = "repair.sh in={0} in2={1} out={2} out2={3}".format(r1, r2, rr1, rr2)
    print(cmd)
    call(cmd, shell=True)
    
    # bbduk
    rb1 = rr1.replace('_rep1.fastq', '_bbduk_1.fastq')
    rb2 = rr2.replace('_rep2.fastq', '_bbduk_2.fastq')
    cmd = "bbduk.sh in={0} in2={1} out={2} out2={3} threads={4}".format(rr1, rr2, rb1, rb2, THREADS)
    print(cmd)
    call(cmd, shell=True)
    
    return rb1, rb2

def process_reads_s(r1, outfolder):
    # bbduk
    rr1 = outfolder + os.path.basename(r1).replace('_1.fastq', '_rep1.fastq')
    rb1 = rr1.replace('_rep1.fastq', '_bbduk.fastq')
    cmd = "bbduk.sh in={0} out={1} threads={2}".format(r1, rb1, THREADS)
    print(cmd)
    call(cmd, shell=True)
    
    return rb1 

SRdb['filtered_fastq1_exists'] = [os.path.exists(x) for x in SRdb['filtered_fastq1']]
SRdb['filtered_fastq2_exists'] = [os.path.exists(x) for x in SRdb['filtered_fastq2']]
SRdb['filtered_fastqS_exists'] = [os.path.exists(x) for x in SRdb['filtered_fastqS']]

# Process paired
for i, row in SRdb[(SRdb['LibraryLayout'] == 'PAIRED') & ((SRdb['filtered_fastq1_exists'] == False) | (SRdb['filtered_fastq2_exists'] == False))].iterrows():
    rb1, rb2 = process_reads(row['fastq1'], row['fastq2'], '/home/mattolm/user_data/Covid_19/reads/filtered/')
    
# Process unpaired
for i, row in SRdb[(SRdb['LibraryLayout'] == 'SINGLE') & (SRdb['filtered_fastqS_exists'] == False)].iterrows():
    b1 = process_reads_s(row['fastq1'], '/home/mattolm/user_data/Covid_19/reads/filtered/')
    
SRdb['filtered_fastq1_exists'] = [os.path.exists(x) for x in SRdb['filtered_fastq1']]
SRdb['filtered_fastq2_exists'] = [os.path.exists(x) for x in SRdb['filtered_fastq2']]
SRdb['filtered_fastqS_exists'] = [os.path.exists(x) for x in SRdb['filtered_fastqS']]
# Out:
# bbduk.sh in=/home/mattolm/user_data/Covid_19/reads/SRR11454606_1.fastq out=/home/mattolm/user_data/Covid_19/reads/filtered/SRR11454606_bbduk.fastq threads=6
# bbduk.sh in=/home/mattolm/user_data/Covid_19/reads/SRR11454607_1.fastq out=/home/mattolm/user_data/Covid_19/reads/filtered/SRR11454607_bbduk.fastq threads=6
# bbduk.sh in=/home/mattolm/user_data/Covid_19/reads/SRR11454608_1.fastq out=/home/mattolm/user_data/Covid_19/reads/filtered/SRR11454608_bbduk.fastq threads=6
# bbduk.sh in=/home/mattolm/user_data/Covid_19/reads/SRR11454609_1.fastq out=/home/mattolm/user_data/Covid_19/reads/filtered/SRR11454609_bbduk.fastq threads=6
# bbduk.sh in=/home/mattolm/user_data/Covid_19/reads/SRR11454610_1.fastq out=/home/mattolm/user_data/Covid_19/reads/filtered/SRR11454610_bbduk.fastq threads=6
# bbduk.sh in=/home/mattolm/user_data/Covid_19/reads/SRR11454611_1.fastq out=/home/mattolm/user_data/Covid_19/reads/filtered/SRR11454611_bbduk.fastq threads=6
# bbduk.sh in=/home/mattolm/user_data/Covid_19/reads/SRR11454612_1.fastq out=/home/mattolm/user_data/Covid_19/reads/filtered/SRR11454612_bbduk.fastq threads=6
# bbduk.sh in=/home/mattolm/user_data/Covid_19/reads/SRR11454613_1.fastq out=/home/mattolm/user_data/Covid_19/reads/filtered/SRR11454613_bbduk.fastq threads=6
# bbduk.sh in=/home/mattolm/user_data/Covid_19/reads/SRR11454614_1.fastq out=/home/mattolm/user_data/Covid_19/reads/filtered/SRR11454614_bbduk.fastq threads=6
# bbduk.sh in=/home/mattolm/user_data/Covid_19/reads/SRR11454615_1.fastq out=/home/mattolm/user_data/Covid_19/reads/filtered/SRR11454615_bbduk.fastq threads=6
# bbduk.sh in=/home/mattolm/user_data/Covid_19/reads/SRR11412291_1.fastq out=/home/mattolm/user_data/Covid_19/reads/filtered/SRR11412291_bbduk.fastq threads=6
# bbduk.sh in=/home/mattolm/user_data/Covid_19/reads/SRR11412292_1.fastq out=/home/mattolm/user_data/Covid_19/reads/filtered/SRR11412292_bbduk.fastq threads=6
# bbduk.sh in=/home/mattolm/user_data/Covid_19/reads/SRR11412293_1.fastq out=/home/mattolm/user_data/Covid_19/reads/filtered/SRR11412293_bbduk.fastq threads=6
# bbduk.sh in=/home/mattolm/user_data/Covid_19/reads/SRR11412294_1.fastq out=/home/mattolm/user_data/Covid_19/reads/filtered/SRR11412294_bbduk.fastq threads=6
# bbduk.sh in=/home/mattolm/user_data/Covid_19/reads/SRR11412290_1.fastq out=/home/mattolm/user_data/Covid_19/reads/filtered/SRR11412290_bbduk.fastq threads=6
# bbduk.sh in=/home/mattolm/user_data/Covid_19/reads/SRR11412289_1.fastq out=/home/mattolm/user_data/Covid_19/reads/filtered/SRR11412289_bbduk.fastq threads=6
# bbduk.sh in=/home/mattolm/user_data/Covid_19/reads/SRR11412288_1.fastq out=/home/mattolm/user_data/Covid_19/reads/filtered/SRR11412288_bbduk.fastq threads=6
# bbduk.sh in=/home/mattolm/user_data/Covid_19/reads/SRR11412287_1.fastq out=/home/mattolm/user_data/Covid_19/reads/filtered/SRR11412287_bbduk.fastq threads=6
# bbduk.sh in=/home/mattolm/user_data/Covid_19/reads/SRR11412286_1.fastq out=/home/mattolm/user_data/Covid_19/reads/filtered/SRR11412286_bbduk.fastq threads=6
# bbduk.sh in=/home/mattolm/user_data/Covid_19/reads/SRR11412285_1.fastq out=/home/mattolm/user_data/Covid_19/reads/filtered/SRR11412285_bbduk.fastq threads=6
# bbduk.sh in=/home/mattolm/user_data/Covid_19/reads/SRR11412284_1.fastq out=/home/mattolm/user_data/Covid_19/reads/filtered/SRR11412284_bbduk.fastq threads=6
# bbduk.sh in=/home/mattolm/user_data/Covid_19/reads/SRR11412283_1.fastq out=/home/mattolm/user_data/Covid_19/reads/filtered/SRR11412283_bbduk.fastq threads=6
# bbduk.sh in=/home/mattolm/user_data/Covid_19/reads/SRR11412279_1.fastq out=/home/mattolm/user_data/Covid_19/reads/filtered/SRR11412279_bbduk.fastq threads=6
# bbduk.sh in=/home/mattolm/user_data/Covid_19/reads/SRR11412280_1.fastq out=/home/mattolm/user_data/Covid_19/reads/filtered/SRR11412280_bbduk.fastq threads=6
# bbduk.sh in=/home/mattolm/user_data/Covid_19/reads/SRR11412281_1.fastq out=/home/mattolm/user_data/Covid_19/reads/filtered/SRR11412281_bbduk.fastq threads=6
# bbduk.sh in=/home/mattolm/user_data/Covid_19/reads/SRR11412282_1.fastq out=/home/mattolm/user_data/Covid_19/reads/filtered/SRR11412282_bbduk.fastq threads=6
# bbduk.sh in=/home/mattolm/user_data/Covid_19/reads/SRR11412275_1.fastq out=/home/mattolm/user_data/Covid_19/reads/filtered/SRR11412275_bbduk.fastq threads=6
# bbduk.sh in=/home/mattolm/user_data/Covid_19/reads/SRR11412276_1.fastq out=/home/mattolm/user_data/Covid_19/reads/filtered/SRR11412276_bbduk.fastq threads=6
# bbduk.sh in=/home/mattolm/user_data/Covid_19/reads/SRR11412277_1.fastq out=/home/mattolm/user_data/Covid_19/reads/filtered/SRR11412277_bbduk.fastq threads=6
# bbduk.sh in=/home/mattolm/user_data/Covid_19/reads/SRR11412278_1.fastq out=/home/mattolm/user_data/Covid_19/reads/filtered/SRR11412278_bbduk.fastq threads=6
# bbduk.sh in=/home/mattolm/user_data/Covid_19/reads/SRR11412274_1.fastq out=/home/mattolm/user_data/Covid_19/reads/filtered/SRR11412274_bbduk.fastq threads=6
# bbduk.sh in=/home/mattolm/user_data/Covid_19/reads/SRR11412273_1.fastq out=/home/mattolm/user_data/Covid_19/reads/filtered/SRR11412273_bbduk.fastq threads=6
# bbduk.sh in=/home/mattolm/user_data/Covid_19/reads/SRR11412272_1.fastq out=/home/mattolm/user_data/Covid_19/reads/filtered/SRR11412272_bbduk.fastq threads=6
# bbduk.sh in=/home/mattolm/user_data/Covid_19/reads/SRR11412271_1.fastq out=/home/mattolm/user_data/Covid_19/reads/filtered/SRR11412271_bbduk.fastq threads=6
# bbduk.sh in=/home/mattolm/user_data/Covid_19/reads/SRR11412270_1.fastq out=/home/mattolm/user_data/Covid_19/reads/filtered/SRR11412270_bbduk.fastq threads=6
# bbduk.sh in=/home/mattolm/user_data/Covid_19/reads/SRR11412269_1.fastq out=/home/mattolm/user_data/Covid_19/reads/filtered/SRR11412269_bbduk.fastq threads=6
# bbduk.sh in=/home/mattolm/user_data/Covid_19/reads/SRR11412268_1.fastq out=/home/mattolm/user_data/Covid_19/reads/filtered/SRR11412268_bbduk.fastq threads=6
# bbduk.sh in=/home/mattolm/user_data/Covid_19/reads/SRR11412267_1.fastq out=/home/mattolm/user_data/Covid_19/reads/filtered/SRR11412267_bbduk.fastq threads=6
# bbduk.sh in=/home/mattolm/user_data/Covid_19/reads/SRR11412266_1.fastq out=/home/mattolm/user_data/Covid_19/reads/filtered/SRR11412266_bbduk.fastq threads=6
# bbduk.sh in=/home/mattolm/user_data/Covid_19/reads/SRR11412265_1.fastq out=/home/mattolm/user_data/Covid_19/reads/filtered/SRR11412265_bbduk.fastq threads=6
# bbduk.sh in=/home/mattolm/user_data/Covid_19/reads/SRR11412264_1.fastq out=/home/mattolm/user_data/Covid_19/reads/filtered/SRR11412264_bbduk.fastq threads=6
# bbduk.sh in=/home/mattolm/user_data/Covid_19/reads/SRR11412263_1.fastq out=/home/mattolm/user_data/Covid_19/reads/filtered/SRR11412263_bbduk.fastq threads=6
# bbduk.sh in=/home/mattolm/user_data/Covid_19/reads/SRR11412262_1.fastq out=/home/mattolm/user_data/Covid_19/reads/filtered/SRR11412262_bbduk.fastq threads=6
# bbduk.sh in=/home/mattolm/user_data/Covid_19/reads/SRR11412261_1.fastq out=/home/mattolm/user_data/Covid_19/reads/filtered/SRR11412261_bbduk.fastq threads=6
# bbduk.sh in=/home/mattolm/user_data/Covid_19/reads/SRR11412260_1.fastq out=/home/mattolm/user_data/Covid_19/reads/filtered/SRR11412260_bbduk.fastq threads=6
# bbduk.sh in=/home/mattolm/user_data/Covid_19/reads/SRR11412259_1.fastq out=/home/mattolm/user_data/Covid_19/reads/filtered/SRR11412259_bbduk.fastq threads=6
# bbduk.sh in=/home/mattolm/user_data/Covid_19/reads/SRR11412258_1.fastq out=/home/mattolm/user_data/Covid_19/reads/filtered/SRR11412258_bbduk.fastq threads=6
# bbduk.sh in=/home/mattolm/user_data/Covid_19/reads/SRR11412257_1.fastq out=/home/mattolm/user_data/Covid_19/reads/filtered/SRR11412257_bbduk.fastq threads=6
# bbduk.sh in=/home/mattolm/user_data/Covid_19/reads/SRR11412256_1.fastq out=/home/mattolm/user_data/Covid_19/reads/filtered/SRR11412256_bbduk.fastq threads=6
# bbduk.sh in=/home/mattolm/user_data/Covid_19/reads/SRR11412255_1.fastq out=/home/mattolm/user_data/Covid_19/reads/filtered/SRR11412255_bbduk.fastq threads=6
# bbduk.sh in=/home/mattolm/user_data/Covid_19/reads/SRR11412254_1.fastq out=/home/mattolm/user_data/Covid_19/reads/filtered/SRR11412254_bbduk.fastq threads=6
# bbduk.sh in=/home/mattolm/user_data/Covid_19/reads/SRR11412251_1.fastq out=/home/mattolm/user_data/Covid_19/reads/filtered/SRR11412251_bbduk.fastq threads=6
# bbduk.sh in=/home/mattolm/user_data/Covid_19/reads/SRR11412253_1.fastq out=/home/mattolm/user_data/Covid_19/reads/filtered/SRR11412253_bbduk.fastq threads=6
# bbduk.sh in=/home/mattolm/user_data/Covid_19/reads/SRR11412252_1.fastq out=/home/mattolm/user_data/Covid_19/reads/filtered/SRR11412252_bbduk.fastq threads=6
# bbduk.sh in=/home/mattolm/user_data/Covid_19/reads/SRR11412250_1.fastq out=/home/mattolm/user_data/Covid_19/reads/filtered/SRR11412250_bbduk.fastq threads=6
# bbduk.sh in=/home/mattolm/user_data/Covid_19/reads/SRR11412249_1.fastq out=/home/mattolm/user_data/Covid_19/reads/filtered/SRR11412249_bbduk.fastq threads=6
# bbduk.sh in=/home/mattolm/user_data/Covid_19/reads/SRR11412248_1.fastq out=/home/mattolm/user_data/Covid_19/reads/filtered/SRR11412248_bbduk.fastq threads=6
# bbduk.sh in=/home/mattolm/user_data/Covid_19/reads/SRR11412247_1.fastq out=/home/mattolm/user_data/Covid_19/reads/filtered/SRR11412247_bbduk.fastq threads=6
# bbduk.sh in=/home/mattolm/user_data/Covid_19/reads/SRR11412243_1.fastq out=/home/mattolm/user_data/Covid_19/reads/filtered/SRR11412243_bbduk.fastq threads=6
# bbduk.sh in=/home/mattolm/user_data/Covid_19/reads/SRR11412244_1.fastq out=/home/mattolm/user_data/Covid_19/reads/filtered/SRR11412244_bbduk.fastq threads=6
# bbduk.sh in=/home/mattolm/user_data/Covid_19/reads/SRR11412245_1.fastq out=/home/mattolm/user_data/Covid_19/reads/filtered/SRR11412245_bbduk.fastq threads=6
# bbduk.sh in=/home/mattolm/user_data/Covid_19/reads/SRR11412246_1.fastq out=/home/mattolm/user_data/Covid_19/reads/filtered/SRR11412246_bbduk.fastq threads=6
# bbduk.sh in=/home/mattolm/user_data/Covid_19/reads/SRR11412242_1.fastq out=/home/mattolm/user_data/Covid_19/reads/filtered/SRR11412242_bbduk.fastq threads=6
# bbduk.sh in=/home/mattolm/user_data/Covid_19/reads/SRR11412241_1.fastq out=/home/mattolm/user_data/Covid_19/reads/filtered/SRR11412241_bbduk.fastq threads=6
# bbduk.sh in=/home/mattolm/user_data/Covid_19/reads/SRR11412240_1.fastq out=/home/mattolm/user_data/Covid_19/reads/filtered/SRR11412240_bbduk.fastq threads=6
# bbduk.sh in=/home/mattolm/user_data/Covid_19/reads/SRR11412239_1.fastq out=/home/mattolm/user_data/Covid_19/reads/filtered/SRR11412239_bbduk.fastq threads=6
# bbduk.sh in=/home/mattolm/user_data/Covid_19/reads/SRR11412238_1.fastq out=/home/mattolm/user_data/Covid_19/reads/filtered/SRR11412238_bbduk.fastq threads=6
# bbduk.sh in=/home/mattolm/user_data/Covid_19/reads/SRR11412237_1.fastq out=/home/mattolm/user_data/Covid_19/reads/filtered/SRR11412237_bbduk.fastq threads=6
# bbduk.sh in=/home/mattolm/user_data/Covid_19/reads/SRR11412236_1.fastq out=/home/mattolm/user_data/Covid_19/reads/filtered/SRR11412236_bbduk.fastq threads=6
# bbduk.sh in=/home/mattolm/user_data/Covid_19/reads/SRR11412235_1.fastq out=/home/mattolm/user_data/Covid_19/reads/filtered/SRR11412235_bbduk.fastq threads=6
# bbduk.sh in=/home/mattolm/user_data/Covid_19/reads/SRR11412231_1.fastq out=/home/mattolm/user_data/Covid_19/reads/filtered/SRR11412231_bbduk.fastq threads=6
# bbduk.sh in=/home/mattolm/user_data/Covid_19/reads/SRR11412232_1.fastq out=/home/mattolm/user_data/Covid_19/reads/filtered/SRR11412232_bbduk.fastq threads=6
# bbduk.sh in=/home/mattolm/user_data/Covid_19/reads/SRR11412233_1.fastq out=/home/mattolm/user_data/Covid_19/reads/filtered/SRR11412233_bbduk.fastq threads=6
# bbduk.sh in=/home/mattolm/user_data/Covid_19/reads/SRR11412234_1.fastq out=/home/mattolm/user_data/Covid_19/reads/filtered/SRR11412234_bbduk.fastq threads=6
# bbduk.sh in=/home/mattolm/user_data/Covid_19/reads/SRR11412227_1.fastq out=/home/mattolm/user_data/Covid_19/reads/filtered/SRR11412227_bbduk.fastq threads=6
# bbduk.sh in=/home/mattolm/user_data/Covid_19/reads/SRR11412228_1.fastq out=/home/mattolm/user_data/Covid_19/reads/filtered/SRR11412228_bbduk.fastq threads=6
# bbduk.sh in=/home/mattolm/user_data/Covid_19/reads/SRR11412229_1.fastq out=/home/mattolm/user_data/Covid_19/reads/filtered/SRR11412229_bbduk.fastq threads=6
# bbduk.sh in=/home/mattolm/user_data/Covid_19/reads/SRR11412230_1.fastq out=/home/mattolm/user_data/Covid_19/reads/filtered/SRR11412230_bbduk.fastq threads=6
# bbduk.sh in=/home/mattolm/user_data/Covid_19/reads/SRR11412226_1.fastq out=/home/mattolm/user_data/Covid_19/reads/filtered/SRR11412226_bbduk.fastq threads=6
# bbduk.sh in=/home/mattolm/user_data/Covid_19/reads/SRR11412223_1.fastq out=/home/mattolm/user_data/Covid_19/reads/filtered/SRR11412223_bbduk.fastq threads=6
# bbduk.sh in=/home/mattolm/user_data/Covid_19/reads/SRR11412225_1.fastq out=/home/mattolm/user_data/Covid_19/reads/filtered/SRR11412225_bbduk.fastq threads=6
# bbduk.sh in=/home/mattolm/user_data/Covid_19/reads/SRR11412224_1.fastq out=/home/mattolm/user_data/Covid_19/reads/filtered/SRR11412224_bbduk.fastq threads=6
# bbduk.sh in=/home/mattolm/user_data/Covid_19/reads/SRR11412222_1.fastq out=/home/mattolm/user_data/Covid_19/reads/filtered/SRR11412222_bbduk.fastq threads=6
# bbduk.sh in=/home/mattolm/user_data/Covid_19/reads/SRR11412221_1.fastq out=/home/mattolm/user_data/Covid_19/reads/filtered/SRR11412221_bbduk.fastq threads=6
# bbduk.sh in=/home/mattolm/user_data/Covid_19/reads/SRR11412220_1.fastq out=/home/mattolm/user_data/Covid_19/reads/filtered/SRR11412220_bbduk.fastq threads=6
# bbduk.sh in=/home/mattolm/user_data/Covid_19/reads/SRR11412219_1.fastq out=/home/mattolm/user_data/Covid_19/reads/filtered/SRR11412219_bbduk.fastq threads=6
# bbduk.sh in=/home/mattolm/user_data/Covid_19/reads/SRR11412218_1.fastq out=/home/mattolm/user_data/Covid_19/reads/filtered/SRR11412218_bbduk.fastq threads=6
# bbduk.sh in=/home/mattolm/user_data/Covid_19/reads/SRR11412217_1.fastq out=/home/mattolm/user_data/Covid_19/reads/filtered/SRR11412217_bbduk.fastq threads=6
# bbduk.sh in=/home/mattolm/user_data/Covid_19/reads/SRR11412216_1.fastq out=/home/mattolm/user_data/Covid_19/reads/filtered/SRR11412216_bbduk.fastq threads=6
# bbduk.sh in=/home/mattolm/user_data/Covid_19/reads/SRR11412215_1.fastq out=/home/mattolm/user_data/Covid_19/reads/filtered/SRR11412215_bbduk.fastq threads=6

# %% [markdown]
# ## Run mapping

# %%
BTL = '/home/mattolm/user_data/Covid_19/genomes/NC_045512.2.fasta.bt2'
ML = '/home/mattolm/user_data/Covid_19/inStrain/mapping/'
s2l = SRdb.set_index('Run')['LibraryLayout'].to_dict()

SRdb['sam_file'] = ["{0}{1}-vs-{2}.sam".format(ML, os.path.basename(BTL), r) for r in SRdb['Run']]
SRdb['mapping_done'] = [os.path.isfile(s) for s in SRdb['sam_file']]

cmd_loc = '/home/mattolm/user_data/Covid_19/Pipeline/Jupyter/cmds/{0}_mapping.txt'.format(d4)
re = open(cmd_loc, 'w')

for i, row in SRdb[SRdb['mapping_done'] == False].iterrows():
#for i, row in SRdb.iterrows():
    sam_loc = row['sam_file']
    if s2l[row['Run']] == 'PAIRED':
        cmd = "bowtie2 -x {3} -1 {0} -2 {1} --no-unal -S {2} -p {4} 2> {2}.log".format(
                row['filtered_fastq1'], row['filtered_fastq2'], sam_loc, BTL, THREADS)
        re.write(cmd + '\n')
    else:
        cmd = "bowtie2 -x {3} -U {0} --no-unal -S {2} -p {4} 2> {2}.log".format(
                row['filtered_fastqS'], '', sam_loc, BTL, THREADS)
        re.write(cmd + '\n')
re.close()

cmd = "cat {0} | bash".format(cmd_loc)
call(cmd, shell=True)

SRdb['mapping_done'] = [os.path.isfile(s) for s in SRdb['sam_file']]
SRdb['mapping_done'].value_counts()
# Out:
# True    159
# Name: mapping_done, dtype: int64

# %% [markdown]
# ## Parse bowtie2 logs for information

# %%
def parse_bt2(log):
    table = defaultdict(list)
    with open(log, 'r') as o:
        for line in o.readlines():
            line = line.strip()
            if 'reads;' in line:
                table['total_reads'].append(int(line.split()[0]))
            if 'paired;' in line:
                table['paired_reads'].append(int(line.split()[0]))
            if 'overall alignment rate' in line:
                table['percent_aligned'].append(float(line.split()[0][:-1]))
    db = pd.DataFrame(table)
    db['aligned_reads'] = db['total_reads'] * (db['percent_aligned'] / 100)
    db['aligned_reads'] = db['aligned_reads'].astype(int)
    return db

dbs = []
SRdb['mapping_log'] = SRdb['sam_file'] + '.log'
SRdb['mapping_log_exists'] = [os.path.exists(x) for x in SRdb['mapping_log']]
for i, row in SRdb.iterrows():
    db = parse_bt2(row['mapping_log'])
    db['Run'] = row['Run']
    dbs.append(db)
Mdb = pd.concat(dbs).reset_index(drop=True)
for col in Mdb.columns:
    if col in ['Run']:
        continue
    r2c = Mdb.set_index('Run')[col].to_dict()
    SRdb[col] = SRdb['Run'].map(r2c)

# %% [markdown]
# ## Run inStrain

# %%
SRdb['inStrain_coverage'] = ["/home/mattolm/user_data/Covid_19/inStrain/profiles/{0}.IS/output/{0}.IS_scaffold_info.tsv".format(os.path.basename(r)) for r in SRdb['sam_file']]
SRdb['inStrain_succeeded'] = [os.path.isfile(s) for s in SRdb['inStrain_coverage']]
SRdb['inStrain_succeeded'].value_counts()
# Out:
# True     123
# False     36
# Name: inStrain_succeeded, dtype: int64

# %%
cmd_loc = '/home/mattolm/user_data/Covid_19/Pipeline/Jupyter/cmds/{0}_instrain.txt'.format(d4)
fasta = '/home/mattolm/user_data/Covid_19/genomes/NC_045512.2.fasta'
genes ='/home/mattolm/user_data/Covid_19/genomes/NC_045512.2.gb'
s2l = SRdb.set_index('Run')['LibraryLayout'].to_dict()

re = open(cmd_loc, 'w')
for i, row in SRdb[SRdb['inStrain_succeeded'] == False].iterrows():
    if s2l[row['Run']] == 'PAIRED': 
        cmd = "inStrain profile {0} {2} -o /home/mattolm/user_data/Covid_19/inStrain/profiles/{1}.IS -p 1 -g {3} --skip_mm_profiling".format(row['sam_file'], os.path.basename(row['sam_file']), fasta, genes)
        re.write(cmd + '\n')
    else:
        cmd = "inStrain profile {0} {2} -o /home/mattolm/user_data/Covid_19/inStrain/profiles/{1}.IS -p 1 --pairing_filter non_discordant -g {3} --skip_mm_profiling".format(row['sam_file'], os.path.basename(row['sam_file']), fasta, genes)
        re.write(cmd + '\n')
re.close()
    
cmd = "cat {0} | parallel -j {1}".format(cmd_loc, THREADS)
print(cmd)
call(cmd, shell=True)
    
SRdb['inStrain_succeeded'] = [os.path.isfile(s) for s in SRdb['inStrain_coverage']]
SRdb['inStrain_succeeded'].value_counts()
# Out:
# cat /home/mattolm/user_data/Covid_19/Pipeline/Jupyter/cmds/02_04_2020_instrain.txt | parallel -j 6
# True     123
# False     36
# Name: inStrain_succeeded, dtype: int64

# %%
print("{0} samples failed inStrain that should have passed".format(len(SRdb[(SRdb['inStrain_succeeded'] == False) & (SRdb['aligned_reads'] > 0)])))
# Out:
# 0 samples failed inStrain that should have passed

# %%
['/'.join(x.split('/')[:-2]) + '/log/log.log' for x in SRdb[(SRdb['inStrain_succeeded'] == False) & (SRdb['aligned_reads'] > 0)]['inStrain_coverage'].tolist()]
# Out:
# []

# %% [markdown]
# # Save information

# %%
# Full
SRdb.to_csv('/home/mattolm/user_data/Covid_19/Pipeline/Jupyter/{0}_SRA_full_info.csv'.format(d4), index=False)
SRdb.head()
# Out:
#   study_accession experiment_accession  \
# 0       SRP254688           SRX8032211
# 1       SRP254688           SRX8032210
# 2       SRP254688           SRX8032209
# 3       SRP254688           SRX8032208
# 4       SRP254688           SRX8032207
#
#                                     experiment_title  \
# 0  RNA-Seq of Homo sapiens: hCov-19 infected pati...
# 1  RNA-Seq of Homo sapiens: hCov-19 infected pati...
# 2  RNA-Seq of Homo sapiens: hCov-19 infected pati...
# 3  RNA-Seq of Homo sapiens: hCov-19 infected pati...
# 4  RNA-Seq of Homo sapiens: hCov-19 infected pati...
#
#                                      experiment_desc  organism_taxid   \
# 0  RNA-Seq of Homo sapiens: hCov-19 infected pati...        2697049.0
# 1  RNA-Seq of Homo sapiens: hCov-19 infected pati...        2697049.0
# 2  RNA-Seq of Homo sapiens: hCov-19 infected pati...        2697049.0
# 3  RNA-Seq of Homo sapiens: hCov-19 infected pati...        2697049.0
# 4  RNA-Seq of Homo sapiens: hCov-19 infected pati...        2697049.0
#
#                                      organism_name library_strategy  \
# 0  Severe acute respiratory syndrome coronavirus 2          RNA-Seq
# 1  Severe acute respiratory syndrome coronavirus 2          RNA-Seq
# 2  Severe acute respiratory syndrome coronavirus 2          RNA-Seq
# 3  Severe acute respiratory syndrome coronavirus 2          RNA-Seq
# 4  Severe acute respiratory syndrome coronavirus 2          RNA-Seq
#
#    library_source library_selection sample_accession  sample_title  \
# 0  TRANSCRIPTOMIC        RANDOM PCR       SRS6404546           NaN
# 1  TRANSCRIPTOMIC        RANDOM PCR       SRS6404545           NaN
# 2  TRANSCRIPTOMIC        RANDOM PCR       SRS6404544           NaN
# 3  TRANSCRIPTOMIC        RANDOM PCR       SRS6404543           NaN
# 4  TRANSCRIPTOMIC        RANDOM PCR       SRS6404542           NaN
#
#           instrument  total_spots   total_size run_accession  run_total_spots  \
# 0   Illumina MiniSeq    5668472.0  489620824.0   SRR11454606        5668472.0
# 1   Illumina MiniSeq    4407436.0  413461584.0   SRR11454607        4407436.0
# 2  Illumina iSeq 100    2690410.0  232046490.0   SRR11454608        2690410.0
# 3        NextSeq 550   17121629.0  517518269.0   SRR11454609       17121629.0
# 4        NextSeq 550   14337950.0  413719955.0   SRR11454610       14337950.0
#
#    run_total_bases                                          run_alias  \
# 0     1.350169e+09   BetaCoV_Tianmen_HBCDC-HB-07_2020_R1_001.fastq.gz
# 1     1.157795e+09     BetaCoV_Wuhan_HBCDC-HB-06_2020_R1_001.fastq.gz
# 2     7.258831e+08  BetaCoV_Jingzhou_HBCDC-HB-01_2020_R1_001.fastq.gz
# 3     1.284122e+09  BetaCoV_Wuhan_HBCDC-HB-02_2020_S10_R1_001.fast...
# 4     1.075346e+09  BetaCoV_Wuhan_HBCDC-HB-03_2020_S24_R1_001.fast...
#
#                                          sra_url_alt  \
# 0  https://sra-download.ncbi.nlm.nih.gov/traces/s...
# 1  https://sra-download.ncbi.nlm.nih.gov/traces/s...
# 2  https://sra-download.ncbi.nlm.nih.gov/traces/s...
# 3  https://sra-download.ncbi.nlm.nih.gov/traces/s...
# 4  https://sra-download.ncbi.nlm.nih.gov/traces/s...
#
#                                              sra_url experiment_alias  \
# 0  https://sra-download.ncbi.nlm.nih.gov/traces/s...              NaN
# 1  https://sra-download.ncbi.nlm.nih.gov/traces/s...              NaN
# 2  https://sra-download.ncbi.nlm.nih.gov/traces/s...              NaN
# 3  https://sra-download.ncbi.nlm.nih.gov/traces/s...              NaN
# 4  https://sra-download.ncbi.nlm.nih.gov/traces/s...              NaN
#
#                                    isolate  \
# 0   human BetaCoV Tianmen HBCDC-HB-07/2020
# 1     human BetaCoV Wuhan HBCDC-HB-06/2020
# 2  human BetaCoV Jingzhou HBCDC-HB-01/2020
# 3     human BetaCoV Wuhan HBCDC-HB-02/2020
# 4     human BetaCoV Wuhan HBCDC-HB-03/2020
#
#                                         collected_by collection_date  \
# 0  Tianmen Center for Disease Control and Prevention      2020-02-08
# 1                                Wuhan Lung Hospital      2020-02-07
# 2  Jingzhou Center for Disease Control and Preven...      2020-01-08
# 3                      The Central Hospital Of Wuhan      2020-01-17
# 4  Union Hospital of Tongji Medical College, Huaz...      2020-01-18
#
#    geo_loc_name          host host_disease isolation_source        lat_lon  \
# 0  China: Hubei  Homo sapiens     COVID-19          Tianmen  not collected
# 1  China: Hubei  Homo sapiens     COVID-19            Wuhan  not collected
# 2  China: Hubei  Homo sapiens     COVID-19         Jingzhou  not collected
# 3  China: Hubei  Homo sapiens     COVID-19            Wuhan  not collected
# 4  China: Hubei  Homo sapiens     COVID-19            Wuhan  not collected
#
#   BioSampleModel source_name cell line cell type treatment strain time point  \
# 0    Pathogen.cl         NaN       NaN       NaN       NaN    NaN        NaN
# 1    Pathogen.cl         NaN       NaN       NaN       NaN    NaN        NaN
# 2    Pathogen.cl         NaN       NaN       NaN       NaN    NaN        NaN
# 3    Pathogen.cl         NaN       NaN       NaN       NaN    NaN        NaN
# 4    Pathogen.cl         NaN       NaN       NaN       NaN    NaN        NaN
#
#   identification_method culture_collection host_description passage_history  \
# 0                   NaN                NaN              NaN             NaN
# 1                   NaN                NaN              NaN             NaN
# 2                   NaN                NaN              NaN             NaN
# 3                   NaN                NaN              NaN             NaN
# 4                   NaN                NaN              NaN             NaN
#
#   sample type Laboratory Host Extraction Method ref_biomaterial  \
# 0         NaN             NaN               NaN             NaN
# 1         NaN             NaN               NaN             NaN
# 2         NaN             NaN               NaN             NaN
# 3         NaN             NaN               NaN             NaN
# 4         NaN             NaN               NaN             NaN
#
#   link_addit_analys  host_age host_sex country sra_url_alt1 sra_url_alt2  \
# 0               NaN       NaN      NaN     NaN          NaN          NaN
# 1               NaN       NaN      NaN     NaN          NaN          NaN
# 2               NaN       NaN      NaN     NaN          NaN          NaN
# 3               NaN       NaN      NaN     NaN          NaN          NaN
# 4               NaN       NaN      NaN     NaN          NaN          NaN
#
#   host_disease_outcome host_disease_stage ena_fastq_url  ena_fastq_ftp  \
# 0                  NaN                NaN           NaN            NaN
# 1                  NaN                NaN           NaN            NaN
# 2                  NaN                NaN           NaN            NaN
# 3                  NaN                NaN           NaN            NaN
# 4                  NaN                NaN           NaN            NaN
#
#            Run   BioProject  \
# 0  SRR11454606  PRJNA616446
# 1  SRR11454607  PRJNA616446
# 2  SRR11454608  PRJNA616446
# 3  SRR11454609  PRJNA616446
# 4  SRR11454610  PRJNA616446
#
#                                             sra_file  sra_exists  \
# 0  /home/mattolm/user_data/Covid_19/reads/SRR1145...        True
# 1  /home/mattolm/user_data/Covid_19/reads/SRR1145...        True
# 2  /home/mattolm/user_data/Covid_19/reads/SRR1145...        True
# 3  /home/mattolm/user_data/Covid_19/reads/SRR1145...        True
# 4  /home/mattolm/user_data/Covid_19/reads/SRR1145...        True
#
#    sra_file_consistant                                             fastq1  \
# 0                 True  /home/mattolm/user_data/Covid_19/reads/SRR1145...
# 1                 True  /home/mattolm/user_data/Covid_19/reads/SRR1145...
# 2                 True  /home/mattolm/user_data/Covid_19/reads/SRR1145...
# 3                 True  /home/mattolm/user_data/Covid_19/reads/SRR1145...
# 4                 True  /home/mattolm/user_data/Covid_19/reads/SRR1145...
#
#                                               fastq2  fastq1_exists  \
# 0  /home/mattolm/user_data/Covid_19/reads/SRR1145...           True
# 1  /home/mattolm/user_data/Covid_19/reads/SRR1145...           True
# 2  /home/mattolm/user_data/Covid_19/reads/SRR1145...           True
# 3  /home/mattolm/user_data/Covid_19/reads/SRR1145...           True
# 4  /home/mattolm/user_data/Covid_19/reads/SRR1145...           True
#
#    fastq2_exists LibraryLayout  \
# 0          False        SINGLE
# 1          False        SINGLE
# 2          False        SINGLE
# 3          False        SINGLE
# 4          False        SINGLE
#
#                                      filtered_fastq1  \
# 0  /home/mattolm/user_data/Covid_19/reads/filtere...
# 1  /home/mattolm/user_data/Covid_19/reads/filtere...
# 2  /home/mattolm/user_data/Covid_19/reads/filtere...
# 3  /home/mattolm/user_data/Covid_19/reads/filtere...
# 4  /home/mattolm/user_data/Covid_19/reads/filtere...
#
#                                      filtered_fastq2  \
# 0  /home/mattolm/user_data/Covid_19/reads/filtere...
# 1  /home/mattolm/user_data/Covid_19/reads/filtere...
# 2  /home/mattolm/user_data/Covid_19/reads/filtere...
# 3  /home/mattolm/user_data/Covid_19/reads/filtere...
# 4  /home/mattolm/user_data/Covid_19/reads/filtere...
#
#                                      filtered_fastqS  filtered_fastq1_exists  \
# 0  /home/mattolm/user_data/Covid_19/reads/filtere...                   False
# 1  /home/mattolm/user_data/Covid_19/reads/filtere...                   False
# 2  /home/mattolm/user_data/Covid_19/reads/filtere...                   False
# 3  /home/mattolm/user_data/Covid_19/reads/filtere...                   False
# 4  /home/mattolm/user_data/Covid_19/reads/filtere...                   False
#
#    filtered_fastq2_exists  filtered_fastqS_exists  \
# 0                   False                    True
# 1                   False                    True
# 2                   False                    True
# 3                   False                    True
# 4                   False                    True
#
#                                             sam_file  mapping_done  \
# 0  /home/mattolm/user_data/Covid_19/inStrain/mapp...          True
# 1  /home/mattolm/user_data/Covid_19/inStrain/mapp...          True
# 2  /home/mattolm/user_data/Covid_19/inStrain/mapp...          True
# 3  /home/mattolm/user_data/Covid_19/inStrain/mapp...          True
# 4  /home/mattolm/user_data/Covid_19/inStrain/mapp...          True
#
#                                          mapping_log  mapping_log_exists  \
# 0  /home/mattolm/user_data/Covid_19/inStrain/mapp...                True
# 1  /home/mattolm/user_data/Covid_19/inStrain/mapp...                True
# 2  /home/mattolm/user_data/Covid_19/inStrain/mapp...                True
# 3  /home/mattolm/user_data/Covid_19/inStrain/mapp...                True
# 4  /home/mattolm/user_data/Covid_19/inStrain/mapp...                True
#
#    total_reads  paired_reads  percent_aligned  aligned_reads  \
# 0      5668472       5668472             0.03           1700
# 1      4407436       4407436             0.25          11018
# 2      2690410       2690410             3.20          86093
# 3     17121629      17121629             0.37          63350
# 4     14337950      14337950             0.87         124740
#
#                                    inStrain_coverage  inStrain_succeeded
# 0  /home/mattolm/user_data/Covid_19/inStrain/prof...                True
# 1  /home/mattolm/user_data/Covid_19/inStrain/prof...                True
# 2  /home/mattolm/user_data/Covid_19/inStrain/prof...                True
# 3  /home/mattolm/user_data/Covid_19/inStrain/prof...                True
# 4  /home/mattolm/user_data/Covid_19/inStrain/prof...                True

# %%
# Basic
PMdb = SRdb[['Run', 'experiment_title', 'experiment_desc', 'sample_accession', 
             'library_strategy', 'library_source', 'library_selection', 'LibraryLayout', 
             'instrument', 'collected_by', 'collection_date', 'isolation_source',
             'total_reads',	'paired_reads', 'percent_aligned', 'aligned_reads']]#, 'BioSample']]
PMdb.to_csv('/home/mattolm/user_data/Covid_19/Pipeline/Jupyter/{0}_SRA_basic_info.csv'.format(d4), index=False)
PMdb.head()
# Out:
#            Run                                   experiment_title  \
# 0  SRR11454606  RNA-Seq of Homo sapiens: hCov-19 infected pati...
# 1  SRR11454607  RNA-Seq of Homo sapiens: hCov-19 infected pati...
# 2  SRR11454608  RNA-Seq of Homo sapiens: hCov-19 infected pati...
# 3  SRR11454609  RNA-Seq of Homo sapiens: hCov-19 infected pati...
# 4  SRR11454610  RNA-Seq of Homo sapiens: hCov-19 infected pati...
#
#                                      experiment_desc sample_accession  \
# 0  RNA-Seq of Homo sapiens: hCov-19 infected pati...       SRS6404546
# 1  RNA-Seq of Homo sapiens: hCov-19 infected pati...       SRS6404545
# 2  RNA-Seq of Homo sapiens: hCov-19 infected pati...       SRS6404544
# 3  RNA-Seq of Homo sapiens: hCov-19 infected pati...       SRS6404543
# 4  RNA-Seq of Homo sapiens: hCov-19 infected pati...       SRS6404542
#
#   library_strategy  library_source library_selection LibraryLayout  \
# 0          RNA-Seq  TRANSCRIPTOMIC        RANDOM PCR        SINGLE
# 1          RNA-Seq  TRANSCRIPTOMIC        RANDOM PCR        SINGLE
# 2          RNA-Seq  TRANSCRIPTOMIC        RANDOM PCR        SINGLE
# 3          RNA-Seq  TRANSCRIPTOMIC        RANDOM PCR        SINGLE
# 4          RNA-Seq  TRANSCRIPTOMIC        RANDOM PCR        SINGLE
#
#           instrument                                       collected_by  \
# 0   Illumina MiniSeq  Tianmen Center for Disease Control and Prevention
# 1   Illumina MiniSeq                                Wuhan Lung Hospital
# 2  Illumina iSeq 100  Jingzhou Center for Disease Control and Preven...
# 3        NextSeq 550                      The Central Hospital Of Wuhan
# 4        NextSeq 550  Union Hospital of Tongji Medical College, Huaz...
#
#   collection_date isolation_source  total_reads  paired_reads  \
# 0      2020-02-08          Tianmen      5668472       5668472
# 1      2020-02-07            Wuhan      4407436       4407436
# 2      2020-01-08         Jingzhou      2690410       2690410
# 3      2020-01-17            Wuhan     17121629      17121629
# 4      2020-01-18            Wuhan     14337950      14337950
#
#    percent_aligned  aligned_reads
# 0             0.03           1700
# 1             0.25          11018
# 2             3.20          86093
# 3             0.37          63350
# 4             0.87         124740

# %%
# Parsed

PLdb = SRdb.copy()

# Add from BioMeta
PLdb = pd.merge(PLdb, BioMeta[['BioProject', 'Group', 'Method', 'Center_ID']], on='BioProject', how='left')

VARIABLES = ['Center_ID', 'Group', 'BioProject', 'Method', 'library_strategy', 'library_source', 'instrument', 'LibraryLayout']
for v in VARIABLES:
    if len(PLdb[PLdb[v].isna()]) > 0:
        print("{0} samples have no {1}".format(len(PLdb[PLdb[v].isna()]), v))

# Add basic instrain
dbs = []
for i, row in PLdb[PLdb['inStrain_succeeded'] == True].iterrows():
    db = pd.read_csv(row['inStrain_coverage'], sep='\t')
    db['Run'] = row['Run']
    dbs.append(db)
COdb = pd.concat(dbs).reset_index(drop=True)

PLdb = pd.merge(PLdb, COdb[['Run', 'coverage', 'breadth']], how='left', on='Run')
assert len(PLdb[(PLdb['coverage'].isna()) & (PLdb['aligned_reads'] > 0)]) == 0

# Filter
DESC_VARS = ['sample_accession', 'experiment_desc', 'collection_date', 'isolation_source']
INFO_VARS = ['total_reads', 'percent_aligned', 'coverage', 'breadth']
PLdb = PLdb[['Run'] + VARIABLES + INFO_VARS + DESC_VARS]

# Print a little description
COV_LIM = 50
BRE_LIM = 0.9

fdb = PLdb[(PLdb['coverage'] >= COV_LIM)]
print("{0} of {1} samples have >={2} coverage".format(len(fdb), len(PLdb), COV_LIM, BRE_LIM))

fdb = PLdb[(PLdb['breadth'] >= BRE_LIM)]
print("{0} of {1} samples have >={3} breadth".format(len(fdb), len(PLdb), COV_LIM, BRE_LIM))

fdb = PLdb[(PLdb['coverage'] >= COV_LIM) & (PLdb['breadth'] >= BRE_LIM)]
print("{0} of {1} samples have >={2} coverage and >={3} breadth".format(len(fdb), len(PLdb), COV_LIM, BRE_LIM))
fdb['Center_ID'].value_counts()

PLdb['Sufficient_cov'] = [((coverage >= COV_LIM) & (breadth >= BRE_LIM)) for coverage, breadth in zip(PLdb['coverage'], PLdb['breadth'])]
PLdb.to_csv('/home/mattolm/user_data/Covid_19/Pipeline/Jupyter/{0}_SRA_parsed_info.csv'.format(d4), index=False)
PLdb.head()
# Out:
# 59 of 159 samples have >=50 coverage
# 60 of 159 samples have >=0.9 breadth
# 50 of 159 samples have >=50 coverage and >=0.9 breadth
#            Run    Center_ID  \
# 0  SRR11454606  Hubei_China
# 1  SRR11454607  Hubei_China
# 2  SRR11454608  Hubei_China
# 3  SRR11454609  Hubei_China
# 4  SRR11454610  Hubei_China
#
#                                                Group   BioProject   Method  \
# 0  Hubei Provincial Center for Disease Control an...  PRJNA616446  RNA-seq
# 1  Hubei Provincial Center for Disease Control an...  PRJNA616446  RNA-seq
# 2  Hubei Provincial Center for Disease Control an...  PRJNA616446  RNA-seq
# 3  Hubei Provincial Center for Disease Control an...  PRJNA616446  RNA-seq
# 4  Hubei Provincial Center for Disease Control an...  PRJNA616446  RNA-seq
#
#   library_strategy  library_source         instrument LibraryLayout  \
# 0          RNA-Seq  TRANSCRIPTOMIC   Illumina MiniSeq        SINGLE
# 1          RNA-Seq  TRANSCRIPTOMIC   Illumina MiniSeq        SINGLE
# 2          RNA-Seq  TRANSCRIPTOMIC  Illumina iSeq 100        SINGLE
# 3          RNA-Seq  TRANSCRIPTOMIC        NextSeq 550        SINGLE
# 4          RNA-Seq  TRANSCRIPTOMIC        NextSeq 550        SINGLE
#
#    total_reads  percent_aligned    coverage   breadth sample_accession  \
# 0      5668472             0.03    6.168746  0.965522       SRS6404546
# 1      4407436             0.25   40.258502  0.997559       SRS6404545
# 2      2690410             3.20  364.855165  0.998428       SRS6404544
# 3     17121629             0.37  139.966692  0.998763       SRS6404543
# 4     14337950             0.87  284.849948  0.998729       SRS6404542
#
#                                      experiment_desc collection_date  \
# 0  RNA-Seq of Homo sapiens: hCov-19 infected pati...      2020-02-08
# 1  RNA-Seq of Homo sapiens: hCov-19 infected pati...      2020-02-07
# 2  RNA-Seq of Homo sapiens: hCov-19 infected pati...      2020-01-08
# 3  RNA-Seq of Homo sapiens: hCov-19 infected pati...      2020-01-17
# 4  RNA-Seq of Homo sapiens: hCov-19 infected pati...      2020-01-18
#
#   isolation_source  Sufficient_cov
# 0          Tianmen           False
# 1            Wuhan           False
# 2         Jingzhou            True
# 3            Wuhan            True
# 4            Wuhan            True

# %%
PLdb['Sufficient_cov'].value_counts()
# Out:
# False    109
# True      50
# Name: Sufficient_cov, dtype: int64
